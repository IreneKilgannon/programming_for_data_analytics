# %% [markdown]
# # The Weather Data

# %% [markdown]
# The weather data was downloaded from [Met Éireann's historical weather website](https://www.met.ie/climate/available-data/historical-data). The data from a number of weather stations was downloaded with the choice of weather station based on their proximity to a wind farm. A number were also selected for the size of the data set. Weather information for Shannon Airport, Dublin Airport and Valentia dates back to the mid-1940's. These larger data sets will be used to analyse long term weather trends in Ireland.
#
# The Met Éireann weather data used for this analysis was recorded hourly. Measurements such as rainfall (mm), wind speed (knots), wind direction (degrees), relative humidity and temperature (Celsius) were recorded.

# %%
# Import modules
import pandas as pd
import matplotlib.pyplot as plt
import glob

# %% [markdown]
# The glob module was used to create a single dataframe of the weather data in a similar method to the electricity data. For an explanation of glob please see [clean_electricity.ipynb](clean_electricity.ipynb).

# %%
# Check the files 
csv_files = glob.glob('data/weather/*.csv')
csv_files
# Out:
# ['data/weather/hly1775Johnstown.csv',
#  'data/weather/hly875Mullingar.csv',
#  'data/weather/hly532DublinAirport.csv',
#  'data/weather/hly1975MtDillon.csv',
#  'data/weather/hly1875Athenry.csv',
#  'data/weather/hly1475Gurteen.csv',
#  'data/weather/hly518ShannonAirport.csv',
#  'data/weather/hly2075Finner.csv',
#  'data/weather/hly1175Newport.csv',
#  'data/weather/hly3904CorkAirport.csv',
#  'data/weather/hly2275Valentia.csv',
#  'data/weather/hly2375Belmullet.csv']

# %% [markdown]
# The weather stations selected for analysis are:
#
# * Athenry, Co. Galway
# * Belmullet, Co. Mayo
# * Cork Airport, Co. Cork
# * Dublin Airport, Dublin
# * Finner, Co. Donegal
# * Gurteen, Co. Tipperary
# * Johnstown Castle, Co. Wexford
# * Mount Dillon, Co. Roscommon
# * Mullingar, Co. Westmeath
# * Newport, Co. Mayo
# * Shannon Airport, Co. Clare
# * Valentia, Co. Kerry

# %%
# Find all csv files in the data/weather
csv_files = glob.glob('data/weather/*.csv')

# Create an empty dataframe to store the combined data
weather_df = pd.DataFrame()

# Loop through each csv file and append contents to weather_df
for csv_file in csv_files:
    
    for skip_rows in [17, 23]:
        try:
            df = pd.read_csv(csv_file,
                             skiprows= skip_rows,
                             na_values= ' ',
                             index_col= 'date',
                             parse_dates= ['date'],
                             usecols= ['date', 'rhum', 'rain', 'temp', 'msl', 'wdsp', 'wddir'],
                             date_format = "%d-%b-%Y %H:%M"
                             )
        except Exception as e:
            continue
        
        # Concatenate the dataframe to weather_df
        weather_df = pd.concat([weather_df, df], axis= 1)

    # Sort Index
    weather_df.sort_index(inplace= True)

weather_df.head()
# Out:
#                      rain  temp  rhum  msl  wdsp  wddir  rain  temp  rhum  \
# date
# 1945-01-01 00:00:00   NaN   NaN   NaN  NaN   NaN    NaN   NaN   NaN   NaN
# 1945-01-01 01:00:00   NaN   NaN   NaN  NaN   NaN    NaN   NaN   NaN   NaN
# 1945-01-01 02:00:00   NaN   NaN   NaN  NaN   NaN    NaN   NaN   NaN   NaN
# 1945-01-01 03:00:00   NaN   NaN   NaN  NaN   NaN    NaN   NaN   NaN   NaN
# 1945-01-01 04:00:00   NaN   NaN   NaN  NaN   NaN    NaN   NaN   NaN   NaN
#
#                      msl  ...  rhum     msl  wdsp  wddir  rain  temp  rhum  \
# date                      ...
# 1945-01-01 00:00:00  NaN  ...  99.0  1037.2   3.0  350.0   NaN   NaN   NaN
# 1945-01-01 01:00:00  NaN  ...  97.0  1037.2   2.0  360.0   NaN   NaN   NaN
# 1945-01-01 02:00:00  NaN  ...  93.0  1037.3   6.0   10.0   NaN   NaN   NaN
# 1945-01-01 03:00:00  NaN  ...  93.0  1037.5   9.0  350.0   NaN   NaN   NaN
# 1945-01-01 04:00:00  NaN  ...  92.0  1037.6   9.0  350.0   NaN   NaN   NaN
#
#                      msl  wdsp  wddir
# date
# 1945-01-01 00:00:00  NaN   NaN    NaN
# 1945-01-01 01:00:00  NaN   NaN    NaN
# 1945-01-01 02:00:00  NaN   NaN    NaN
# 1945-01-01 03:00:00  NaN   NaN    NaN
# 1945-01-01 04:00:00  NaN   NaN    NaN
#
# [5 rows x 72 columns]

# %%
# Write full unprocessed data to a CSV file
weather_df.to_csv('data/weather/merged_data/full_weather.csv')

# %% [markdown]
# As the energy data dates from 2014 to 2024, the weather data for this time period will be selected for weather and wind energy analysis.

# %%
# Select weather data from 2014.
weather_df = weather_df['2014' :'2024']
weather_df.head()
# Out:
#                      rain  temp  rhum    msl  wdsp  wddir  rain  temp  rhum  \
# date
# 2014-01-01 00:00:00   0.0   7.6  76.0  992.4  13.0  220.0   0.0   3.4  90.0
# 2014-01-01 01:00:00   0.0   6.6  77.0  992.4  11.0  230.0   0.0   3.0  92.0
# 2014-01-01 02:00:00   0.0   6.7  83.0  991.7   9.0  210.0   0.0   3.0  92.0
# 2014-01-01 03:00:00   0.0   7.5  81.0  991.1  10.0  210.0   0.1   3.0  93.0
# 2014-01-01 04:00:00   0.0   8.0  82.0  989.6  11.0  200.0   0.0   2.8  94.0
#
#                        msl  ...  rhum    msl  wdsp  wddir  rain  temp  rhum  \
# date                        ...
# 2014-01-01 00:00:00  989.8  ...  80.0  988.7   9.0  180.0   0.0   7.1  80.0
# 2014-01-01 01:00:00  989.7  ...  81.0  987.5   7.0  180.0   0.0   6.4  82.0
# 2014-01-01 02:00:00  989.1  ...  82.0  986.2   9.0  180.0   0.1   7.2  86.0
# 2014-01-01 03:00:00  988.5  ...  88.0  984.4   9.0  180.0   0.1   7.0  85.0
# 2014-01-01 04:00:00  987.4  ...  88.0  981.9   8.0  160.0   1.0   6.6  91.0
#
#                        msl  wdsp  wddir
# date
# 2014-01-01 00:00:00  984.0  17.0  210.0
# 2014-01-01 01:00:00  983.7  17.0  200.0
# 2014-01-01 02:00:00  983.2  15.0  200.0
# 2014-01-01 03:00:00  982.5  16.0  190.0
# 2014-01-01 04:00:00  981.6  16.0  190.0
#
# [5 rows x 72 columns]

# %%
weather_df.shape
# Out:
# (96432, 72)

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 96432 entries, 2014-01-01 00:00:00 to 2024-12-31 23:00:00
# Freq: h
# Data columns (total 72 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   rain    96403 non-null  float64
#  1   temp    96404 non-null  float64
#  2   rhum    96404 non-null  float64
#  3   msl     96404 non-null  float64
#  4   wdsp    96398 non-null  float64
#  5   wddir   96402 non-null  float64
#  6   rain    96422 non-null  float64
#  7   temp    96424 non-null  float64
#  8   rhum    96424 non-null  float64
#  9   msl     96424 non-null  float64
#  10  wdsp    96419 non-null  float64
#  11  wddir   96422 non-null  float64
#  12  rain    96432 non-null  float64
#  13  temp    96432 non-null  float64
#  14  rhum    96432 non-null  float64
#  15  msl     96432 non-null  float64
#  16  wdsp    96432 non-null  int64
#  17  wddir   96432 non-null  float64
#  18  rain    96391 non-null  float64
#  19  temp    96394 non-null  float64
#  20  rhum    96387 non-null  float64
#  21  msl     95930 non-null  float64
#  22  wdsp    96384 non-null  float64
#  23  wddir   96391 non-null  float64
#  24  rain    96419 non-null  float64
#  25  temp    96420 non-null  float64
#  26  rhum    96408 non-null  float64
#  27  msl     96332 non-null  float64
#  28  wdsp    96406 non-null  float64
#  29  wddir   96406 non-null  float64
#  30  rain    96395 non-null  float64
#  31  temp    96404 non-null  float64
#  32  rhum    96403 non-null  float64
#  33  msl     96384 non-null  float64
#  34  wdsp    96397 non-null  float64
#  35  wddir   96409 non-null  float64
#  36  rain    96432 non-null  float64
#  37  temp    96432 non-null  float64
#  38  rhum    96432 non-null  float64
#  39  msl     96432 non-null  float64
#  40  wdsp    96421 non-null  float64
#  41  wddir   96421 non-null  float64
#  42  rain    96431 non-null  float64
#  43  temp    96432 non-null  float64
#  44  rhum    96432 non-null  float64
#  45  msl     96432 non-null  float64
#  46  wdsp    96432 non-null  float64
#  47  wddir   96432 non-null  float64
#  48  rain    96356 non-null  float64
#  49  temp    96357 non-null  float64
#  50  rhum    96353 non-null  float64
#  51  msl     96354 non-null  float64
#  52  wdsp    96356 non-null  float64
#  53  wddir   96322 non-null  float64
#  54  rain    96432 non-null  float64
#  55  temp    96432 non-null  float64
#  56  rhum    96432 non-null  float64
#  57  msl     96432 non-null  float64
#  58  wdsp    96432 non-null  float64
#  59  wddir   96432 non-null  float64
#  60  rain    96430 non-null  float64
#  61  temp    96432 non-null  float64
#  62  rhum    96432 non-null  float64
#  63  msl     96432 non-null  float64
#  64  wdsp    96388 non-null  float64
#  65  wddir   96323 non-null  float64
#  66  rain    96432 non-null  float64
#  67  temp    96432 non-null  float64
#  68  rhum    96432 non-null  float64
#  69  msl     96432 non-null  float64
#  70  wdsp    96432 non-null  float64
#  71  wddir   96432 non-null  float64
# dtypes: float64(71), int64(1)
# memory usage: 53.7 MB

# %% [markdown]
# This large data set has 95689 rows and 72 columns. All the columns have the correct data type of float.

# %%
# Count of the number of missing values
weather_df.isna().sum().sum()
# Out:
# 2022

# %%
# Check for missing values
weather_df.isna().sum()
# Out:
# rain     29
# temp     28
# rhum     28
# msl      28
# wdsp     34
#          ..
# temp      0
# rhum      0
# msl       0
# wdsp      0
# wddir     0
# Length: 72, dtype: int64

# %%
# Find rows with missing information
null_data = weather_df[weather_df.isnull().any(axis=1)]
null_data
# Out:
#                      rain  temp  rhum     msl  wdsp  wddir  rain  temp  rhum  \
# date
# 2014-04-10 12:00:00   0.0  11.6  68.0  1022.8  10.0  230.0   0.1   9.4  93.0
# 2014-04-10 13:00:00   0.0  11.3  69.0  1022.5  10.0  240.0   0.0  10.4  91.0
# 2014-04-10 14:00:00   0.0  11.4  73.0  1022.0  11.0  230.0   1.3  10.3  96.0
# 2014-04-10 15:00:00   0.0  10.9  82.0  1021.9  12.0  240.0   0.4  11.8  83.0
# 2014-08-26 15:00:00   0.0  16.5  82.0  1008.5  15.0   60.0   0.0  15.5  81.0
# ...                   ...   ...   ...     ...   ...    ...   ...   ...   ...
# 2024-08-19 06:00:00   0.4  14.4  96.0  1012.3   8.0  190.0   0.0  12.2  89.0
# 2024-08-19 07:00:00   0.2  14.8  96.0  1011.4  10.0  180.0   0.0  12.9  90.0
# 2024-08-19 08:00:00   0.0  15.3  93.0  1011.2   9.0  190.0   0.0  13.8  88.0
# 2024-08-19 09:00:00   0.0  15.8  89.0  1010.7  12.0  190.0   0.0  15.0  86.0
# 2024-08-19 10:00:00   0.9  15.7  95.0  1009.0  13.0  190.0   0.3  14.7  89.0
#
#                         msl  ...  rhum     msl  wdsp  wddir  rain  temp  rhum  \
# date                         ...
# 2014-04-10 12:00:00  1021.5  ...  89.0  1023.8   9.0  340.0   0.0  10.5  69.0
# 2014-04-10 13:00:00  1020.9  ...  69.0  1023.8  10.0  330.0   0.0  11.0  71.0
# 2014-04-10 14:00:00  1021.0  ...  67.0  1024.0  10.0  320.0   0.0  10.9  64.0
# 2014-04-10 15:00:00  1021.2  ...  62.0  1024.1   9.0  330.0   0.0  11.1  64.0
# 2014-08-26 15:00:00  1010.8  ...  77.0  1007.7   4.0  260.0   0.0  16.7  73.0
# ...                     ...  ...   ...     ...   ...    ...   ...   ...   ...
# 2024-08-19 06:00:00  1010.0  ...  89.0  1007.7  10.0  170.0   0.0  15.0  89.0
# 2024-08-19 07:00:00  1009.6  ...  92.0  1007.0  10.0  160.0   0.3  15.1  89.0
# 2024-08-19 08:00:00  1009.2  ...  91.0  1003.6  14.0  160.0   3.8  12.7  86.0
# 2024-08-19 09:00:00  1008.0  ...  95.0  1002.2  17.0  160.0   2.8  11.6  91.0
# 2024-08-19 10:00:00  1005.6  ...  96.0  1000.9  17.0  160.0   0.9  14.3  93.0
#
#                         msl  wdsp  wddir
# date
# 2014-04-10 12:00:00  1022.0   9.0  290.0
# 2014-04-10 13:00:00  1022.1  10.0  280.0
# 2014-04-10 14:00:00  1022.4  10.0  280.0
# 2014-04-10 15:00:00  1022.5   9.0  270.0
# 2014-08-26 15:00:00  1010.5  10.0  100.0
# ...                     ...   ...    ...
# 2024-08-19 06:00:00  1006.5  11.0  200.0
# 2024-08-19 07:00:00  1005.5  14.0  200.0
# 2024-08-19 08:00:00  1004.8  17.0  180.0
# 2024-08-19 09:00:00  1003.8  10.0  220.0
# 2024-08-19 10:00:00  1002.3  11.0  160.0
#
# [968 rows x 72 columns]

# %%
# Plot missing values
fig, ax = plt.subplots(figsize = (15,5))
weather_df.isna().sum().plot(kind= 'bar')
plt.show()

# %% [markdown]
# Overall, the number of missing data points, 2022 instances, is low relative to the size of the data set. Only 968 rows have missing data. The missing data will be interpolated rather than dropping the rows with missing data with [dropna()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html), or using forward fill or backward fill with [fillna()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html) to replace the missing data. As the data is taken at hourly intervals, for most situations interpolation should be suitable. Interpolation can be performed with the interpolate() function or fillna(method = 'linear'). This [YouTube video](https://www.youtube.com/watch?v=QXpilXhDsNA) explains linear interpolation in simple terms. Linear interpolation replaces the missing data point between two values, with values between the start point and end point.
#
# This [blog](https://llego.dev/posts/filling-missing-values-pandas-fillna-interpolate/) demonstrates the used of fillna() and interpolate(). Linear interpolation is the default method with interpolate().
#
# There are no index time points missing. This will simplify the task of merging the weather and wind energy data.

# %%
# Interpolate the missing data
weather_df.interpolate(method = 'linear', inplace= True)

# %% [markdown]
# One advantage of excluding the location data when loading the CSV files into pandas is that is simplified the task of calculating the row averages of columns with the same name. If the location of the data was included as part of the column name, grouping the columns by name to calculate countrywide averages would not have been possible.
#
# [Transpose()](https://www.geeksforgeeks.org/python-pandas-dataframe-transpose/) allows for the conversion of rows into columns and vice versa. The mean of columns with the same name was calculated using [groupby()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html). The code from [Stackoverflow.com](https://stackoverflow.com/questions/68233237/computing-row-average-of-columns-with-same-name-in-pandas) was used to complete this part of the task.

# %%
# Compute row average for the columns
weather_df_mean = weather_df.T.groupby(weather_df.columns).mean().T.round(2)

# %% [markdown]
# The columns were [renamed](https://pandas.pydata.org/docs/user_guide/basics.html#basics-rename) to included the units of measurement.

# %%
# Rename columns 
weather_df_mean.rename({'msl': 'Pressure (hPa)', 
                        'rain': 'Rain (mm)', 
                        'temp': 'Temp (°C)', 
                        'wddir': 'Wind Direction (deg)', 
                        'wdsp': 'Wind Speed (knots)', 
                        'rhum': 'Relative Humidity (%)'}, 
                        axis = 'columns',
                        inplace= True)

# %%
# Check the dataframe
weather_df_mean.head()
# Out:
#                      Pressure (hPa)  Rain (mm)  Relative Humidity (%)  \
# date
# 2014-01-01 00:00:00          988.63       0.02                  83.17
# 2014-01-01 01:00:00          988.32       0.01                  85.67
# 2014-01-01 02:00:00          987.72       0.03                  87.17
# 2014-01-01 03:00:00          986.86       0.15                  87.75
# 2014-01-01 04:00:00          985.55       0.20                  89.33
#
#                      Temp (°C)  Wind Direction (deg)  Wind Speed (knots)
# date
# 2014-01-01 00:00:00       5.52                189.17               11.58
# 2014-01-01 01:00:00       5.03                186.67               10.17
# 2014-01-01 02:00:00       5.09                170.83                9.17
# 2014-01-01 03:00:00       5.11                165.00                9.33
# 2014-01-01 04:00:00       5.21                157.50                9.75

# %%
# Write the cleaned data to CSV file
weather_df_mean.to_csv('data/weather/merged_data/weather_analysis.csv')

# %% [markdown]
# How does the mean of the weather compare with the individual weather data?

# %%
# Group by weather_df, the untransposed dataframe by monthly
weather_df_monthly = weather_df.resample('ME').mean()

# %%
# Plot Wind Speed from full data set vs Mean Wind Speed
weather_df_monthly['wdsp'].plot(figsize= (15,5))

weather_df_mean['Wind Speed (knots)'].resample('ME').mean().plot(color = 'black', linestyle = '--', label = 'Mean wind speed')

plt.title('Wind Speeds at Different Locations Compared with Mean Wind Speed')
plt.ylabel('Wind Speed (knots)')
plt.legend(bbox_to_anchor = (1, 1), loc = 'upper left')
plt.savefig('plots/Wind_Speeds_Locations.png')
plt.show()

# %% [markdown]
# This plot confirms that the choice of weather stations reflects an accurate mean wind speed. Originally Sherkin Island, Co Cork and Mace Head, Co. Galway were included. However, their wind speeds were significantly higher than other locations and thus the mean wind speeds was not representative of the bulk of the weather stations. As there are no wind farms close to these locations, they were removed from the weather data set.

# %% [markdown]
# ## References
#
# [Move the legend outside the plot](https://saturncloud.io/blog/legend-outside-the-plot-in-python-matplotlib/#:~:text=To%20move%20the%20legend%20outside,parameters%20of%20the%20legend%20function.&text=The%20bbox_to_anchor%20parameter%20specifies%20the,legend's%20anchor%20point%20should%20be.)

# %% [markdown]
# ***
#
# End
